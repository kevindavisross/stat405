# %%
from symbulate import *
# %matplotlib inline

# %%
def exp_unif():
    x = Exponential(1).draw()
    y = Uniform(0, x).draw()
    return x, y

X, Y = RV(ProbabilitySpace(exp_unif))

(X & Y).sim(1000).plot()
