# %%
from symbulate import *
# %matplotlib inline

# %%
P = [[1/3, 1/3, 1/3],
    [0.5, 0, 0.5],
    [0.1, 0.3, 0.6]]

init = [1, 0, 0]

X = MarkovChain(P, init)

x=X.sim(1)

# %%
x.plot()

# %%
x[5]
# Out:
#     <table>
#       <thead>
#         <th width="10%">Index</th>
#         <th width="90%">Result</th>
#       </thead>
#       <tbody>
#
#         <tr>
#           <td>0</td><td>1</td>
#         </tr>
#
#       </tbody>
#     </table>

# %%
print(X.sim(1)[0:500])
