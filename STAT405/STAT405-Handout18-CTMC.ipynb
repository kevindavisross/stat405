# %%
from symbulate import *
# %matplotlib inline

# %%
Q = [[-1, 0.4,  0.6],
     [0.8/3, -1/3, 0.2/3],
     [0.9/5, 0.1/5, -1/5]]

pi0 = [1, 0, 0]

states = [1, 2, 3]

X = ContinuousTimeMarkovChain(Q, pi0, states)

X.sim(1).plot()

# %%
X[1].sim(10000).plot()

# %%
X[10].sim(10000).plot()

# %%
X[50].sim(10000).plot()
